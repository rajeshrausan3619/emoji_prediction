# %%
import emoji
import pandas as pd
import numpy as np

# %%
emoji.EMOJI_UNICODE
# Out:
# {':1st_place_medal:': '🥇',
#  ':2nd_place_medal:': '🥈',
#  ':3rd_place_medal:': '🥉',
#  ':AB_button_(blood_type):': '🆎',
#  ':ATM_sign:': '🏧',
#  ':A_button_(blood_type):': '🅰',
#  ':A_button_(blood_type)_selector:': '🅰️',
#  ':Afghanistan:': '🇦🇫',
#  ':Aland_Islands:': '🇦🇽',
#  ':Albania:': '🇦🇱',
#  ':Algeria:': '🇩🇿',
#  ':American_Samoa:': '🇦🇸',
#  ':Andorra:': '🇦🇩',
#  ':Angola:': '🇦🇴',
#  ':Anguilla:': '🇦🇮',
#  ':Antarctica:': '🇦🇶',
#  ':Antigua_&_Barbuda:': '🇦🇬',
#  ':Aquarius:': '♒',
#  ':Argentina:': '🇦🇷',
#  ':Aries:': '♈',
#  ':Armenia:': '🇦🇲',
#  ':Aruba:': '🇦🇼',
#  ':Ascension_Island:': '🇦🇨',
#  ':Australia:': '🇦🇺',
#  ':Austria:': '🇦🇹',
#  ':Azerbaijan:': '🇦🇿',
#  ':BACK_arrow:': '🔙',
#  ':B_button_(blood_type):': '🅱',
#  ':B_button_(blood_type)_selector:': '🅱️',
#  ':Bahamas:': '🇧🇸',
#  ':Bahrain:': '🇧🇭',
#  ':Bangladesh:': '🇧🇩',
#  ':Barbados:': '🇧🇧',
#  ':Belarus:': '🇧🇾',
#  ':Belgium:': '🇧🇪',
#  ':Belize:': '🇧🇿',
#  ':Benin:': '🇧🇯',
#  ':Bermuda:': '🇧🇲',
#  ':Bhutan:': '🇧🇹',
#  ':Bolivia:': '🇧🇴',
#  ':Bosnia_&_Herzegovina:': '🇧🇦',
#  ':Botswana:': '🇧🇼',
#  ':Bouvet_Island:': '🇧🇻',
#  ':Brazil:': '🇧🇷',
#  ':British_Indian_Ocean_Territory:': '🇮🇴',
#  ':British_Virgin_Islands:': '🇻🇬',
#  ':Brunei:': '🇧🇳',
#  ':Bulgaria:': '🇧🇬',
#  ':Burkina_Faso:': '🇧🇫',
#  ':Burundi:': '🇧🇮',
#  ':CL_button:': '🆑',
#  ':COOL_button:': '🆒',
#  ':Cambodia:': '🇰🇭',
#  ':Cameroon:': '🇨🇲',
#  ':Canada:': '🇨🇦',
#  ':Canary_Islands:': '🇮🇨',
#  ':Cancer:': '♋',
#  ':Cape_Verde:': '🇨🇻',
#  ':Capricorn:': '♑',
#  ':Caribbean_Netherlands:': '🇧🇶',
#  ':Cayman_Islands:': '🇰🇾',
#  ':Central_African_Republic:': '🇨🇫',
#  ':Ceuta_&_Melilla:': '🇪🇦',
#  ':Chad:': '🇹🇩',
#  ':Chile:': '🇨🇱',
#  ':China:': '🇨🇳',
#  ':Christmas_Island:': '🇨🇽',
#  ':Christmas_tree:': '🎄',
#  ':Clipperton_Island:': '🇨🇵',
#  ':Cocos_(Keeling)_Islands:': '🇨🇨',
#  ':Colombia:': '🇨🇴',
#  ':Comoros:': '🇰🇲',
#  ':Congo_-_Brazzaville:': '🇨🇬',
#  ':Congo_-_Kinshasa:': '🇨🇩',
#  ':Cook_Islands:': '🇨🇰',
#  ':Costa_Rica:': '🇨🇷',
#  ':Croatia:': '🇭🇷',
#  ':Cuba:': '🇨🇺',
#  ':Curaçao:': '🇨🇼',
#  ':Cyprus:': '🇨🇾',
#  ':Czechia:': '🇨🇿',
#  ':Côte_d’Ivoire:': '🇨🇮',
#  ':Denmark:': '🇩🇰',
#  ':Diego_Garcia:': '🇩🇬',
#  ':Djibouti:': '🇩🇯',
#  ':Dominica:': '🇩🇲',
#  ':Dominican_Republic:': '🇩🇴',
#  ':END_arrow:': '🔚',
#  ':Ecuador:': '🇪🇨',
#  ':Egypt:': '🇪🇬',
#  ':El_Salvador:': '🇸🇻',
#  ':England:': '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f',
#  ':Equatorial_Guinea:': '🇬🇶',
#  ':Eritrea:': '🇪🇷',
#  ':Estonia:': '🇪🇪',
#  ':Ethiopia:': '🇪🇹',
#  ':European_Union:': '🇪🇺',
#  ':FREE_button:': '🆓',
#  ':Falkland_Islands:': '🇫🇰',
#  ':Faroe_Islands:': '🇫🇴',
#  ':Fiji:': '🇫🇯',
#  ':Finland:': '🇫🇮',
#  ':France:': '🇫🇷',
#  ':French_Guiana:': '🇬🇫',
#  ':French_Polynesia:': '🇵🇫',
#  ':French_Southern_Territories:': '🇹🇫',
#  ':Gabon:': '🇬🇦',
#  ':Gambia:': '🇬🇲',
#  ':Gemini:': '♊',
#  ':Georgia:': '🇬🇪',
#  ':Germany:': '🇩🇪',
#  ':Ghana:': '🇬🇭',
#  ':Gibraltar:': '🇬🇮',
#  ':Greece:': '🇬🇷',
#  ':Greenland:': '🇬🇱',
#  ':Grenada:': '🇬🇩',
#  ':Guadeloupe:': '🇬🇵',
#  ':Guam:': '🇬🇺',
#  ':Guatemala:': '🇬🇹',
#  ':Guernsey:': '🇬🇬',
#  ':Guinea-Bissau:': '🇬🇼',
#  ':Guinea:': '🇬🇳',
#  ':Guyana:': '🇬🇾',
#  ':Haiti:': '🇭🇹',
#  ':Heard_&_McDonald_Islands:': '🇭🇲',
#  ':Honduras:': '🇭🇳',
#  ':Hong_Kong_SAR_China:': '🇭🇰',
#  ':Hungary:': '🇭🇺',
#  ':ID_button:': '🆔',
#  ':Iceland:': '🇮🇸',
#  ':India:': '🇮🇳',
#  ':Indonesia:': '🇮🇩',
#  ':Iran:': '🇮🇷',
#  ':Iraq:': '🇮🇶',
#  ':Ireland:': '🇮🇪',
#  ':Isle_of_Man:': '🇮🇲',
#  ':Israel:': '🇮🇱',
#  ':Italy:': '🇮🇹',
#  ':Jamaica:': '🇯🇲',
#  ':Japan:': '🇯🇵',
#  ':Japanese_acceptable_button:': '🉑',
#  ':Japanese_application_button:': '🈸',
#  ':Japanese_bargain_button:': '🉐',
#  ':Japanese_castle:': '🏯',
#  ':Japanese_congratulations_button:': '㊗',
#  ':Japanese_discount_button:': '🈹',
#  ':Japanese_dolls:': '🎎',
#  ':Japanese_free_of_charge_button:': '🈚',
#  ':Japanese_here_button:': '🈁',
#  ':Japanese_monthly_amount_button:': '🈷',
#  ':Japanese_no_vacancy_button:': '🈵',
#  ':Japanese_not_free_of_charge_button:': '🈶',
#  ':Japanese_open_for_business_button:': '🈺',
#  ':Japanese_passing_grade_button:': '🈴',
#  ':Japanese_post_office:': '🏣',
#  ':Japanese_prohibited_button:': '🈲',
#  ':Japanese_reserved_button:': '🈯',
#  ':Japanese_secret_button:': '㊙',
#  ':Japanese_service_charge_button:': '🈂',
#  ':Japanese_symbol_for_beginner:': '🔰',
#  ':Japanese_vacancy_button:': '🈳',
#  ':Japanese_congratulations_button_selector:': '㊗️',
#  ':Japanese_monthly_amount_button_selector:': '🈷️',
#  ':Japanese_secret_button_selector:': '㊙️',
#  ':Japanese_service_charge_button_selector:': '🈂️',
#  ':Jersey:': '🇯🇪',
#  ':Jordan:': '🇯🇴',
#  ':Kazakhstan:': '🇰🇿',
#  ':Kenya:': '🇰🇪',
#  ':Kiribati:': '🇰🇮',
#  ':Kosovo:': '🇽🇰',
#  ':Kuwait:': '🇰🇼',
#  ':Kyrgyzstan:': '🇰🇬',
#  ':Laos:': '🇱🇦',
#  ':Latvia:': '🇱🇻',
#  ':Lebanon:': '🇱🇧',
#  ':Leo:': '♌',
#  ':Lesotho:': '🇱🇸',
#  ':Liberia:': '🇱🇷',
#  ':Libra:': '♎',
#  ':Libya:': '🇱🇾',
#  ':Liechtenstein:': '🇱🇮',
#  ':Lithuania:': '🇱🇹',
#  ':Luxembourg:': '🇱🇺',
#  ':Macau_SAR_China:': '🇲🇴',
#  ':Macedonia:': '🇲🇰',
#  ':Madagascar:': '🇲🇬',
#  ':Malawi:': '🇲🇼',
#  ':Malaysia:': '🇲🇾',
#  ':Maldives:': '🇲🇻',
#  ':Mali:': '🇲🇱',
#  ':Malta:': '🇲🇹',
#  ':Marshall_Islands:': '🇲🇭',
#  ':Martinique:': '🇲🇶',
#  ':Mauritania:': '🇲🇷',
#  ':Mauritius:': '🇲🇺',
#  ':Mayotte:': '🇾🇹',
#  ':Mexico:': '🇲🇽',
#  ':Micronesia:': '🇫🇲',
#  ':Moldova:': '🇲🇩',
#  ':Monaco:': '🇲🇨',
#  ':Mongolia:': '🇲🇳',
#  ':Montenegro:': '🇲🇪',
#  ':Montserrat:': '🇲🇸',
#  ':Morocco:': '🇲🇦',
#  ':Mozambique:': '🇲🇿',
#  ':Mrs._Claus:': '🤶',
#  ':Mrs._Claus_dark_skin_tone:': '🤶🏿',
#  ':Mrs._Claus_light_skin_tone:': '🤶🏻',
#  ':Mrs._Claus_medium-dark_skin_tone:': '🤶🏾',
#  ':Mrs._Claus_medium-light_skin_tone:': '🤶🏼',
#  ':Mrs._Claus_medium_skin_tone:': '🤶🏽',
#  ':Myanmar_(Burma):': '🇲🇲',
#  ':NEW_button:': '🆕',
#  ':NG_button:': '🆖',
#  ':Namibia:': '🇳🇦',
#  ':Nauru:': '🇳🇷',
#  ':Nepal:': '🇳🇵',
#  ':Netherlands:': '🇳🇱',
#  ':New_Caledonia:': '🇳🇨',
#  ':New_Zealand:': '🇳🇿',
#  ':Nicaragua:': '🇳🇮',
#  ':Niger:': '🇳🇪',
#  ':Nigeria:': '🇳🇬',
#  ':Niue:': '🇳🇺',
#  ':Norfolk_Island:': '🇳🇫',
#  ':North_Korea:': '🇰🇵',
#  ':Northern_Mariana_Islands:': '🇲🇵',
#  ':Norway:': '🇳🇴',
#  ':OK_button:': '🆗',
#  ':OK_hand:': '👌',
#  ':OK_hand_dark_skin_tone:': '👌🏿',
#  ':OK_hand_light_skin_tone:': '👌🏻',
#  ':OK_hand_medium-dark_skin_tone:': '👌🏾',
#  ':OK_hand_medium-light_skin_tone:': '👌🏼',
#  ':OK_hand_medium_skin_tone:': '👌🏽',
#  ':ON!_arrow:': '🔛',
#  ':O_button_(blood_type):': '🅾',
#  ':O_button_(blood_type)_selector:': '🅾️',
#  ':Oman:': '🇴🇲',
#  ':Ophiuchus:': '⛎',
#  ':P_button:': '🅿',
#  ':P_button_selector:': '🅿️',
#  ':Pakistan:': '🇵🇰',
#  ':Palau:': '🇵🇼',
#  ':Palestinian_Territories:': '🇵🇸',
#  ':Panama:': '🇵🇦',
#  ':Papua_New_Guinea:': '🇵🇬',
#  ':Paraguay:': '🇵🇾',
#  ':Peru:': '🇵🇪',
#  ':Philippines:': '🇵🇭',
#  ':Pisces:': '♓',
#  ':Pitcairn_Islands:': '🇵🇳',
#  ':Poland:': '🇵🇱',
#  ':Portugal:': '🇵🇹',
#  ':Puerto_Rico:': '🇵🇷',
#  ':Qatar:': '🇶🇦',
#  ':Romania:': '🇷🇴',
#  ':Russia:': '🇷🇺',
#  ':Rwanda:': '🇷🇼',
#  ':Réunion:': '🇷🇪',
#  ':SOON_arrow:': '🔜',
#  ':SOS_button:': '🆘',
#  ':Sagittarius:': '♐',
#  ':Samoa:': '🇼🇸',
#  ':San_Marino:': '🇸🇲',
#  ':Santa_Claus:': '🎅',
#  ':Santa_Claus_dark_skin_tone:': '🎅🏿',
#  ':Santa_Claus_light_skin_tone:': '🎅🏻',
#  ':Santa_Claus_medium-dark_skin_tone:': '🎅🏾',
#  ':Santa_Claus_medium-light_skin_tone:': '🎅🏼',
#  ':Santa_Claus_medium_skin_tone:': '🎅🏽',
#  ':Saudi_Arabia:': '🇸🇦',
#  ':Scorpio:': '♏',
#  ':Scotland:': '🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#  ':Senegal:': '🇸🇳',
#  ':Serbia:': '🇷🇸',
#  ':Seychelles:': '🇸🇨',
#  ':Sierra_Leone:': '🇸🇱',
#  ':Singapore:': '🇸🇬',
#  ':Sint_Maarten:': '🇸🇽',
#  ':Slovakia:': '🇸🇰',
#  ':Slovenia:': '🇸🇮',
#  ':Solomon_Islands:': '🇸🇧',
#  ':Somalia:': '🇸🇴',
#  ':South_Africa:': '🇿🇦',
#  ':South_Georgia_&_South_Sandwich_Islands:': '🇬🇸',
#  ':South_Korea:': '🇰🇷',
#  ':South_Sudan:': '🇸🇸',
#  ':Spain:': '🇪🇸',
#  ':Sri_Lanka:': '🇱🇰',
#  ':St._Barthélemy:': '🇧🇱',
#  ':St._Helena:': '🇸🇭',
#  ':St._Kitts_&_Nevis:': '🇰🇳',
#  ':St._Lucia:': '🇱🇨',
#  ':St._Martin:': '🇲🇫',
#  ':St._Pierre_&_Miquelon:': '🇵🇲',
#  ':St._Vincent_&_Grenadines:': '🇻🇨',
#  ':Statue_of_Liberty:': '🗽',
#  ':Sudan:': '🇸🇩',
#  ':Suriname:': '🇸🇷',
#  ':Svalbard_&_Jan_Mayen:': '🇸🇯',
#  ':Swaziland:': '🇸🇿',
#  ':Sweden:': '🇸🇪',
#  ':Switzerland:': '🇨🇭',
#  ':Syria:': '🇸🇾',
#  ':São_Tomé_&_Príncipe:': '🇸🇹',
#  ':T-Rex:': '🦖',
#  ':TOP_arrow:': '🔝',
#  ':Taiwan:': '🇹🇼',
#  ':Tajikistan:': '🇹🇯',
#  ':Tanzania:': '🇹🇿',
#  ':Taurus:': '♉',
#  ':Thailand:': '🇹🇭',
#  ':Timor-Leste:': '🇹🇱',
#  ':Togo:': '🇹🇬',
#  ':Tokelau:': '🇹🇰',
#  ':Tokyo_tower:': '🗼',
#  ':Tonga:': '🇹🇴',
#  ':Trinidad_&_Tobago:': '🇹🇹',
#  ':Tristan_da_Cunha:': '🇹🇦',
#  ':Tunisia:': '🇹🇳',
#  ':Turkey:': '🇹🇷',
#  ':Turkmenistan:': '🇹🇲',
#  ':Turks_&_Caicos_Islands:': '🇹🇨',
#  ':Tuvalu:': '🇹🇻',
#  ':U.S._Outlying_Islands:': '🇺🇲',
#  ':U.S._Virgin_Islands:': '🇻🇮',
#  ':UP!_button:': '🆙',
#  ':Uganda:': '🇺🇬',
#  ':Ukraine:': '🇺🇦',
#  ':United_Arab_Emirates:': '🇦🇪',
#  ':United_Kingdom:': '🇬🇧',
#  ':United_Nations:': '🇺🇳',
#  ':United_States:': '🇺🇸',
#  ':Uruguay:': '🇺🇾',
#  ':Uzbekistan:': '🇺🇿',
#  ':VS_button:': '🆚',
#  ':Vanuatu:': '🇻🇺',
#  ':Vatican_City:': '🇻🇦',
#  ':Venezuela:': '🇻🇪',
#  ':Vietnam:': '🇻🇳',
#  ':Virgo:': '♍',
#  ':Wales:': '🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f',
#  ':Wallis_&_Futuna:': '🇼🇫',
#  ':Western_Sahara:': '🇪🇭',
#  ':Yemen:': '🇾🇪',
#  ':Zambia:': '🇿🇲',
#  ':Zimbabwe:': '🇿🇼',
#  ':abacus:': '🧮',
#  ':adhesive_bandage:': '\U0001fa79',
#  ':admission_tickets:': '🎟',
#  ':admission_tickets_selector:': '🎟️',
#  ':adult:': '🧑',
#  ':adult_dark_skin_tone:': '🧑🏿',
#  ':adult_light_skin_tone:': '🧑🏻',
#  ':adult_medium-dark_skin_tone:': '🧑🏾',
#  ':adult_medium-light_skin_tone:': '🧑🏼',
#  ':adult_medium_skin_tone:': '🧑🏽',
#  ':aerial_tramway:': '🚡',
#  ':airplane:': '✈',
#  ':airplane_arrival:': '🛬',
#  ':airplane_departure:': '🛫',
#  ':airplane_selector:': '✈️',
#  ':alarm_clock:': '⏰',
#  ':alembic:': '⚗',
#  ':alembic_selector:': '⚗️',
#  ':alien:': '👽',
#  ':alien_monster:': '👾',
#  ':ambulance:': '🚑',
#  ':american_football:': '🏈',
#  ':amphora:': '🏺',
#  ':anchor:': '⚓',
#  ':anger_symbol:': '💢',
#  ':angry_face:': '😠',
#  ':angry_face_with_horns:': '👿',
#  ':anguished_face:': '😧',
#  ':ant:': '🐜',
#  ':antenna_bars:': '📶',
#  ':anxious_face_with_sweat:': '😰',
#  ':articulated_lorry:': '🚛',
#  ':artist_palette:': '🎨',
#  ':astonished_face:': '😲',
#  ':atom_symbol:': '⚛',
#  ':atom_symbol_selector:': '⚛️',
#  ':auto_rickshaw:': '\U0001f6fa',
#  ':automobile:': '🚗',
#  ':avocado:': '🥑',
#  ':axe:': '\U0001fa93',
#  ':baby:': '👶',
#  ':baby_angel:': '👼',
#  ':baby_angel_dark_skin_tone:': '👼🏿',
#  ':baby_angel_light_skin_tone:': '👼🏻',
#  ':baby_angel_medium-dark_skin_tone:': '👼🏾',
#  ':baby_angel_medium-light_skin_tone:': '👼🏼',
#  ':baby_angel_medium_skin_tone:': '👼🏽',
#  ':baby_bottle:': '🍼',
#  ':baby_chick:': '🐤',
#  ':baby_dark_skin_tone:': '👶🏿',
#  ':baby_light_skin_tone:': '👶🏻',
#  ':baby_medium-dark_skin_tone:': '👶🏾',
#  ':baby_medium-light_skin_tone:': '👶🏼',
#  ':baby_medium_skin_tone:': '👶🏽',
#  ':baby_symbol:': '🚼',
#  ':backhand_index_pointing_down:': '👇',
#  ':backhand_index_pointing_down_dark_skin_tone:': '👇🏿',
#  ':backhand_index_pointing_down_light_skin_tone:': '👇🏻',
#  ':backhand_index_pointing_down_medium-dark_skin_tone:': '👇🏾',
#  ':backhand_index_pointing_down_medium-light_skin_tone:': '👇🏼',
#  ':backhand_index_pointing_down_medium_skin_tone:': '👇🏽',
#  ':backhand_index_pointing_left:': '👈',
#  ':backhand_index_pointing_left_dark_skin_tone:': '👈🏿',
#  ':backhand_index_pointing_left_light_skin_tone:': '👈🏻',
#  ':backhand_index_pointing_left_medium-dark_skin_tone:': '👈🏾',
#  ':backhand_index_pointing_left_medium-light_skin_tone:': '👈🏼',
#  ':backhand_index_pointing_left_medium_skin_tone:': '👈🏽',
#  ':backhand_index_pointing_right:': '👉',
#  ':backhand_index_pointing_right_dark_skin_tone:': '👉🏿',
#  ':backhand_index_pointing_right_light_skin_tone:': '👉🏻',
#  ':backhand_index_pointing_right_medium-dark_skin_tone:': '👉🏾',
#  ':backhand_index_pointing_right_medium-light_skin_tone:': '👉🏼',
#  ':backhand_index_pointing_right_medium_skin_tone:': '👉🏽',
#  ':backhand_index_pointing_up:': '👆',
#  ':backhand_index_pointing_up_dark_skin_tone:': '👆🏿',
#  ':backhand_index_pointing_up_light_skin_tone:': '👆🏻',
#  ':backhand_index_pointing_up_medium-dark_skin_tone:': '👆🏾',
#  ':backhand_index_pointing_up_medium-light_skin_tone:': '👆🏼',
#  ':backhand_index_pointing_up_medium_skin_tone:': '👆🏽',
#  ':bacon:': '🥓',
#  ':badger:': '🦡',
#  ':badminton:': '🏸',
#  ':bagel:': '🥯',
#  ':baggage_claim:': '🛄',
#  ':baguette_bread:': '🥖',
#  ':balance_scale:': '⚖',
#  ':balance_scale_selector:': '⚖️',
#  ':bald:': '🦲',
#  ':bald_man:': '👨\u200d🦲',
#  ':bald_woman:': '👩\u200d🦲',
#  ':ballet_shoes:': '\U0001fa70',
#  ':balloon:': '🎈',
#  ':ballot_box_with_ballot:': '🗳',
#  ':ballot_box_with_ballot_selector:': '🗳️',
#  ':ballot_box_with_check:': '☑',
#  ':banana:': '🍌',
#  ':banjo:': '\U0001fa95',
#  ':bank:': '🏦',
#  ':bar_chart:': '📊',
#  ':barber_pole:': '💈',
#  ':baseball:': '⚾',
#  ':basket:': '🧺',
#  ':basketball:': '🏀',
#  ':bat:': '🦇',
#  ':bathtub:': '🛁',
#  ':battery:': '🔋',
#  ':beach_with_umbrella:': '🏖',
#  ':beach_with_umbrella_selector:': '🏖️',
#  ':beaming_face_with_smiling_eyes:': '😁',
#  ':bear_face:': '🐻',
#  ':bearded_person:': '🧔',
#  ':bearded_person_dark_skin_tone:': '🧔🏿',
#  ':bearded_person_light_skin_tone:': '🧔🏻',
#  ':bearded_person_medium-dark_skin_tone:': '🧔🏾',
#  ':bearded_person_medium-light_skin_tone:': '🧔🏼',
#  ':bearded_person_medium_skin_tone:': '🧔🏽',
#  ':beating_heart:': '💓',
#  ':bed:': '🛏',
#  ':bed_selector:': '🛏️',
#  ':beer_mug:': '🍺',
#  ':bell:': '🔔',
#  ':bell_with_slash:': '🔕',
#  ':bellhop_bell:': '🛎',
#  ':bellhop_bell_selector:': '🛎️',
#  ':bento_box:': '🍱',
#  ':beverage_box:': '\U0001f9c3',
#  ':bicycle:': '🚲',
#  ':bikini:': '👙',
#  ':billed_cap:': '🧢',
#  ':biohazard:': '☣',
#  ':biohazard_selector:': '☣️',
#  ':bird:': '🐦',
#  ':birthday_cake:': '🎂',
#  ':black_circle:': '⚫',
#  ':black_flag:': '🏴',
#  ':black_heart:': '🖤',
#  ':black_large_square:': '⬛',
#  ':black_medium-small_square:': '◾',
#  ':black_medium_square:': '◼',
#  ':black_medium_square_selector:': '◼️',
#  ':black_nib:': '✒',
#  ':black_nib_selector:': '✒️',
#  ':black_small_square:': '▪',
#  ':black_small_square_selector:': '▪️',
#  ':black_square_button:': '🔲',
#  ':blond-haired_man:': '👱\u200d♂️',
#  ':blond-haired_man_dark_skin_tone:': '👱🏿\u200d♂️',
#  ':blond-haired_man_light_skin_tone:': '👱🏻\u200d♂️',
#  ':blond-haired_man_medium-dark_skin_tone:': '👱🏾\u200d♂️',
#  ':blond-haired_man_medium-light_skin_tone:': '👱🏼\u200d♂️',
#  ':blond-haired_man_medium_skin_tone:': '👱🏽\u200d♂️',
#  ':blond-haired_person:': '👱',
#  ':blond-haired_person_dark_skin_tone:': '👱🏿',
#  ':blond-haired_person_light_skin_tone:': '👱🏻',
#  ':blond-haired_person_medium-dark_skin_tone:': '👱🏾',
#  ':blond-haired_person_medium-light_skin_tone:': '👱🏼',
#  ':blond-haired_person_medium_skin_tone:': '👱🏽',
#  ':blond-haired_woman:': '👱\u200d♀️',
#  ':blond-haired_woman_dark_skin_tone:': '👱🏿\u200d♀️',
#  ':blond-haired_woman_light_skin_tone:': '👱🏻\u200d♀️',
#  ':blond-haired_woman_medium-dark_skin_tone:': '👱🏾\u200d♀️',
#  ':blond-haired_woman_medium-light_skin_tone:': '👱🏼\u200d♀️',
#  ':blond-haired_woman_medium_skin_tone:': '👱🏽\u200d♀️',
#  ':blossom:': '🌼',
#  ':blowfish:': '🐡',
#  ':blue_book:': '📘',
#  ':blue_circle:': '🔵',
#  ':blue_heart:': '💙',
#  ':blue_square:': '\U0001f7e6',
#  ':boar:': '🐗',
#  ':bomb:': '💣',
#  ':bone:': '🦴',
#  ':bookmark:': '🔖',
#  ':bookmark_tabs:': '📑',
#  ':books:': '📚',
#  ':bottle_with_popping_cork:': '🍾',
#  ':bouquet:': '💐',
#  ':bow_and_arrow:': '🏹',
#  ':bowl_with_spoon:': '🥣',
#  ':bowling:': '🎳',
#  ':boxing_glove:': '🥊',
#  ':boy:': '👦',
#  ':boy_dark_skin_tone:': '👦🏿',
#  ':boy_light_skin_tone:': '👦🏻',
#  ':boy_medium-dark_skin_tone:': '👦🏾',
#  ':boy_medium-light_skin_tone:': '👦🏼',
#  ':boy_medium_skin_tone:': '👦🏽',
#  ':brain:': '🧠',
#  ':bread:': '🍞',
#  ':breast-feeding:': '🤱',
#  ':breast-feeding_dark_skin_tone:': '🤱🏿',
#  ':breast-feeding_light_skin_tone:': '🤱🏻',
#  ':breast-feeding_medium-dark_skin_tone:': '🤱🏾',
#  ':breast-feeding_medium-light_skin_tone:': '🤱🏼',
#  ':breast-feeding_medium_skin_tone:': '🤱🏽',
#  ':brick:': '🧱',
#  ':bride_with_veil:': '👰',
#  ':bride_with_veil_dark_skin_tone:': '👰🏿',
#  ':bride_with_veil_light_skin_tone:': '👰🏻',
#  ':bride_with_veil_medium-dark_skin_tone:': '👰🏾',
#  ':bride_with_veil_medium-light_skin_tone:': '👰🏼',
#  ':bride_with_veil_medium_skin_tone:': '👰🏽',
#  ':bridge_at_night:': '🌉',
#  ':briefcase:': '💼',
#  ':briefs:': '\U0001fa72',
#  ':bright_button:': '🔆',
#  ':broccoli:': '🥦',
#  ':broken_heart:': '💔',
#  ':broom:': '🧹',
#  ':brown_circle:': '\U0001f7e4',
#  ':brown_heart:': '\U0001f90e',
#  ':brown_square:': '\U0001f7eb',
#  ':bug:': '🐛',
#  ':building_construction:': '🏗',
#  ':building_construction_selector:': '🏗️',
#  ':bullet_train:': '🚅',
#  ':burrito:': '🌯',
#  ':bus:': '🚌',
#  ':bus_stop:': '🚏',
#  ':bust_in_silhouette:': '👤',
#  ':busts_in_silhouette:': '👥',
#  ':butter:': '\U0001f9c8',
#  ':butterfly:': '🦋',
#  ':cactus:': '🌵',
#  ':calendar:': '📅',
#  ':call_me_hand:': '🤙',
#  ':call_me_hand_dark_skin_tone:': '🤙🏿',
#  ':call_me_hand_light_skin_tone:': '🤙🏻',
#  ':call_me_hand_medium-dark_skin_tone:': '🤙🏾',
#  ':call_me_hand_medium-light_skin_tone:': '🤙🏼',
#  ':call_me_hand_medium_skin_tone:': '🤙🏽',
#  ':camel:': '🐪',
#  ':camera:': '📷',
#  ':camera_with_flash:': '📸',
#  ':camping:': '🏕',
#  ':camping_selector:': '🏕️',
#  ':candle:': '🕯',
#  ':candle_selector:': '🕯️',
#  ':candy:': '🍬',
#  ':canned_food:': '🥫',
#  ':canoe:': '🛶',
#  ':card_file_box:': '🗃',
#  ':card_file_box_selector:': '🗃️',
#  ':card_index:': '📇',
#  ':card_index_dividers:': '🗂',
#  ':card_index_dividers_selector:': '🗂️',
#  ':carousel_horse:': '🎠',
#  ':carp_streamer:': '🎏',
#  ':carrot:': '🥕',
#  ':castle:': '🏰',
#  ':cat:': '🐈',
#  ':cat_face:': '🐱',
#  ':cat_face_with_tears_of_joy:': '😹',
#  ':cat_face_with_wry_smile:': '😼',
#  ':chains:': '⛓',
#  ':chains_selector:': '⛓️',
#  ':chair:': '\U0001fa91',
#  ':chart_decreasing:': '📉',
#  ':chart_increasing:': '📈',
#  ':chart_increasing_with_yen:': '💹',
#  ':check_box_with_check:': '☑️',
#  ':check_mark:': '✔️',
#  ':cheese_wedge:': '🧀',
#  ':chequered_flag:': '🏁',
#  ':cherries:': '🍒',
#  ':cherry_blossom:': '🌸',
#  ':chess_pawn:': '♟',
#  ':chess_pawn_selector:': '♟️',
#  ':chestnut:': '🌰',
#  ':chicken:': '🐔',
#  ':child:': '🧒',
#  ':child_dark_skin_tone:': '🧒🏿',
#  ':child_light_skin_tone:': '🧒🏻',
#  ':child_medium-dark_skin_tone:': '🧒🏾',
#  ':child_medium-light_skin_tone:': '🧒🏼',
#  ':child_medium_skin_tone:': '🧒🏽',
#  ':children_crossing:': '🚸',
#  ':chipmunk:': '🐿',
#  ':chipmunk_selector:': '🐿️',
#  ':chocolate_bar:': '🍫',
#  ':chopsticks:': '🥢',
#  ':church:': '⛪',
#  ':cigarette:': '🚬',
#  ':cinema:': '🎦',
#  ':circled_M:': 'Ⓜ',
#  ':circled_M_selector:': 'Ⓜ️',
#  ':circus_tent:': '🎪',
#  ':cityscape:': '🏙',
#  ':cityscape_at_dusk:': '🌆',
#  ':cityscape_selector:': '🏙️',
#  ':clamp:': '🗜',
#  ':clamp_selector:': '🗜️',
#  ':clapper_board:': '🎬',
#  ':clapping_hands:': '👏',
#  ':clapping_hands_dark_skin_tone:': '👏🏿',
#  ':clapping_hands_light_skin_tone:': '👏🏻',
#  ':clapping_hands_medium-dark_skin_tone:': '👏🏾',
#  ':clapping_hands_medium-light_skin_tone:': '👏🏼',
#  ':clapping_hands_medium_skin_tone:': '👏🏽',
#  ':classical_building:': '🏛',
#  ':classical_building_selector:': '🏛️',
#  ':clinking_beer_mugs:': '🍻',
#  ':clinking_glasses:': '🥂',
#  ':clipboard:': '📋',
#  ':clockwise_vertical_arrows:': '🔃',
#  ':closed_book:': '📕',
#  ':closed_mailbox_with_lowered_flag:': '📪',
#  ':closed_mailbox_with_raised_flag:': '📫',
#  ':closed_umbrella:': '🌂',
#  ':cloud:': '☁',
#  ':cloud_selector:': '☁️',
#  ':cloud_with_lightning:': '🌩',
#  ':cloud_with_lightning_and_rain:': '⛈',
#  ':cloud_with_lightning_and_rain_selector:': '⛈️',
#  ':cloud_with_lightning_selector:': '🌩️',
#  ':cloud_with_rain:': '🌧',
#  ':cloud_with_rain_selector:': '🌧️',
#  ':cloud_with_snow:': '🌨',
#  ':cloud_with_snow_selector:': '🌨️',
#  ':clown_face:': '🤡',
#  ':club_suit:': '♣',
#  ':club_suit_selector:': '♣️',
#  ':clutch_bag:': '👝',
#  ':coat:': '🧥',
#  ':cocktail_glass:': '🍸',
#  ':coconut:': '🥥',
#  ':coffin:': '⚰',
#  ':coffin_selector:': '⚰️',
#  ':cold_face:': '🥶',
#  ':collision:': '💥',
#  ':comet:': '☄',
#  ':comet_selector:': '☄️',
#  ':compass:': '🧭',
#  ':computer_disk:': '💽',
#  ':computer_mouse:': '🖱',
#  ':computer_mouse_selector:': '🖱️',
#  ':confetti_ball:': '🎊',
#  ':confounded_face:': '😖',
#  ':confused_face:': '😕',
#  ':construction:': '🚧',
#  ':construction_worker:': '👷',
#  ':construction_worker_dark_skin_tone:': '👷🏿',
#  ':construction_worker_light_skin_tone:': '👷🏻',
#  ':construction_worker_medium-dark_skin_tone:': '👷🏾',
#  ':construction_worker_medium-light_skin_tone:': '👷🏼',
#  ':construction_worker_medium_skin_tone:': '👷🏽',
#  ':control_knobs:': '🎛',
#  ':control_knobs_selector:': '🎛️',
#  ':convenience_store:': '🏪',
#  ':cooked_rice:': '🍚',
#  ':cookie:': '🍪',
#  ':cooking:': '🍳',
#  ':copyright:': '©',
#  ':copyright_selector:': '©️',
#  ':couch_and_lamp:': '🛋',
#  ':couch_and_lamp_selector:': '🛋️',
#  ':counterclockwise_arrows_button:': '🔄',
#  ':couple_with_heart-man-man:': '👨\u200d❤\u200d👨',
#  ':couple_with_heart-woman-man:': '👩\u200d❤\u200d👨',
#  ':couple_with_heart-woman-woman:': '👩\u200d❤\u200d👩',
#  ':couple_with_heart:': '💑',
#  ':couple_with_heart_man_man:': '👨\u200d❤️\u200d👨',
#  ':couple_with_heart_woman_man:': '👩\u200d❤️\u200d👨',
#  ':couple_with_heart_woman_woman:': '👩\u200d❤️\u200d👩',
#  ':cow:': '🐄',
#  ':cow_face:': '🐮',
#  ':cowboy_hat_face:': '🤠',
#  ':crab:': '🦀',
#  ':crayon:': '🖍',
#  ':crayon_selector:': '🖍️',
#  ':credit_card:': '💳',
#  ':crescent_moon:': '🌙',
#  ':cricket:': '🦗',
#  ':cricket_game:': '🏏',
#  ':crocodile:': '🐊',
#  ':croissant:': '🥐',
#  ':cross_mark:': '❌',
#  ':cross_mark_button:': '❎',
#  ':crossed_fingers:': '🤞',
#  ':crossed_fingers_dark_skin_tone:': '🤞🏿',
#  ':crossed_fingers_light_skin_tone:': '🤞🏻',
#  ':crossed_fingers_medium-dark_skin_tone:': '🤞🏾',
#  ':crossed_fingers_medium-light_skin_tone:': '🤞🏼',
#  ':crossed_fingers_medium_skin_tone:': '🤞🏽',
#  ':crossed_flags:': '🎌',
#  ':crossed_swords:': '⚔',
#  ':crossed_swords_selector:': '⚔️',
#  ':crown:': '👑',
#  ':crying_cat_face:': '😿',
#  ':crying_face:': '😢',
#  ':crystal_ball:': '🔮',
#  ':cucumber:': '🥒',
#  ':cup_with_straw:': '🥤',
#  ':cupcake:': '🧁',
#  ':curling_stone:': '🥌',
#  ':curly-haired_man:': '👨\u200d🦱',
#  ':curly-haired_woman:': '👩\u200d🦱',
#  ':curly_hair:': '🦱',
#  ':curly_loop:': '➰',
#  ':currency_exchange:': '💱',
#  ':curry_rice:': '🍛',
#  ':custard:': '🍮',
#  ':customs:': '🛃',
#  ':cut_of_meat:': '🥩',
#  ':cyclone:': '🌀',
#  ':dagger:': '🗡',
#  ':dagger_selector:': '🗡️',
#  ':dango:': '🍡',
#  ':dark_skin_tone:': '🏿',
#  ':dashing_away:': '💨',
#  ':deaf_man-dark_skin_tone:': '\U0001f9cf🏿\u200d♂',
#  ':deaf_man-dark_skin_tone_selector:': '\U0001f9cf🏿\u200d♂️',
#  ':deaf_man-light_skin_tone:': '\U0001f9cf🏻\u200d♂',
#  ':deaf_man-light_skin_tone_selector:': '\U0001f9cf🏻\u200d♂️',
#  ':deaf_man-medium-dark_skin_tone:': '\U0001f9cf🏾\u200d♂',
#  ':deaf_man-medium-dark_skin_tone_selector:': '\U0001f9cf🏾\u200d♂️',
#  ':deaf_man-medium-light_skin_tone:': '\U0001f9cf🏼\u200d♂',
#  ':deaf_man-medium-light_skin_tone_selector:': '\U0001f9cf🏼\u200d♂️',
#  ':deaf_man-medium_skin_tone:': '\U0001f9cf🏽\u200d♂',
#  ':deaf_man-medium_skin_tone_selector:': '\U0001f9cf🏽\u200d♂️',
#  ':deaf_man:': '\U0001f9cf\u200d♂',
#  ':deaf_man_selector:': '\U0001f9cf\u200d♂️',
#  ':deaf_person-dark_skin_tone:': '\U0001f9cf🏿',
#  ':deaf_person-light_skin_tone:': '\U0001f9cf🏻',
#  ':deaf_person-medium-dark_skin_tone:': '\U0001f9cf🏾',
#  ':deaf_person-medium-light_skin_tone:': '\U0001f9cf🏼',
#  ':deaf_person-medium_skin_tone:': '\U0001f9cf🏽',
#  ':deaf_person:': '\U0001f9cf',
#  ':deaf_woman-dark_skin_tone:': '\U0001f9cf🏿\u200d♀',
#  ':deaf_woman-dark_skin_tone_selector:': '\U0001f9cf🏿\u200d♀️',
#  ':deaf_woman-light_skin_tone:': '\U0001f9cf🏻\u200d♀',
#  ':deaf_woman-light_skin_tone_selector:': '\U0001f9cf🏻\u200d♀️',
#  ':deaf_woman-medium-dark_skin_tone:': '\U0001f9cf🏾\u200d♀',
#  ':deaf_woman-medium-dark_skin_tone_selector:': '\U0001f9cf🏾\u200d♀️',
#  ':deaf_woman-medium-light_skin_tone:': '\U0001f9cf🏼\u200d♀',
#  ':deaf_woman-medium-light_skin_tone_selector:': '\U0001f9cf🏼\u200d♀️',
#  ':deaf_woman-medium_skin_tone:': '\U0001f9cf🏽\u200d♀',
#  ':deaf_woman-medium_skin_tone_selector:': '\U0001f9cf🏽\u200d♀️',
#  ':deaf_woman:': '\U0001f9cf\u200d♀',
#  ':deaf_woman_selector:': '\U0001f9cf\u200d♀️',
#  ':deciduous_tree:': '🌳',
#  ':deer:': '🦌',
#  ':delivery_truck:': '🚚',
#  ':department_store:': '🏬',
#  ':derelict_house:': '🏚',
#  ':derelict_house_selector:': '🏚️',
#  ':desert:': '🏜',
#  ':desert_island:': '🏝',
#  ':desert_island_selector:': '🏝️',
#  ':desert_selector:': '🏜️',
#  ':desktop_computer:': '🖥',
#  ':desktop_computer_selector:': '🖥️',
#  ':detective:': '🕵',
#  ':detective_dark_skin_tone:': '🕵🏿',
#  ':detective_light_skin_tone:': '🕵🏻',
#  ':detective_medium-dark_skin_tone:': '🕵🏾',
#  ':detective_medium-light_skin_tone:': '🕵🏼',
#  ':detective_medium_skin_tone:': '🕵🏽',
#  ':detective_selector:': '🕵️',
#  ':diamond_suit:': '♦',
#  ':diamond_suit_selector:': '♦️',
#  ':diamond_with_a_dot:': '💠',
#  ':dim_button:': '🔅',
#  ':direct_hit:': '🎯',
#  ':disappointed_face:': '😞',
#  ':diving_mask:': '\U0001f93f',
#  ':diya_lamp:': '\U0001fa94',
#  ':dizzy:': '💫',
#  ':dizzy_face:': '😵',
#  ':dna:': '🧬',
#  ':dog:': '🐕',
#  ':dog_face:': '🐶',
#  ':dollar_banknote:': '💵',
#  ':dolphin:': '🐬',
#  ':door:': '🚪',
#  ':dotted_six-pointed_star:': '🔯',
#  ':double_curly_loop:': '➿',
#  ':double_exclamation_mark:': '‼',
#  ':double_exclamation_mark_selector:': '‼️',
#  ':doughnut:': '🍩',
#  ':dove:': '🕊',
#  ':dove_selector:': '🕊️',
#  ':down-left_arrow:': '↙',
#  ':down-left_arrow_selector:': '↙️',
#  ':down-right_arrow:': '↘',
#  ':down-right_arrow_selector:': '↘️',
#  ':down_arrow:': '⬇',
#  ':down_arrow_selector:': '⬇️',
#  ':downcast_face_with_sweat:': '😓',
#  ':downwards_button:': '🔽',
#  ':dragon:': '🐉',
#  ':dragon_face:': '🐲',
#  ':dress:': '👗',
#  ':drooling_face:': '🤤',
#  ':drop_of_blood:': '\U0001fa78',
#  ':droplet:': '💧',
#  ':drum:': '🥁',
#  ':duck:': '🦆',
#  ':dumpling:': '🥟',
#  ':dvd:': '📀',
#  ':e-mail:': '📧',
#  ':eagle:': '🦅',
#  ':ear:': '👂',
#  ':ear_dark_skin_tone:': '👂🏿',
#  ':ear_light_skin_tone:': '👂🏻',
#  ':ear_medium-dark_skin_tone:': '👂🏾',
#  ':ear_medium-light_skin_tone:': '👂🏼',
#  ':ear_medium_skin_tone:': '👂🏽',
#  ':ear_of_corn:': '🌽',
#  ':ear_with_hearing_aid-dark_skin_tone:': '\U0001f9bb🏿',
#  ':ear_with_hearing_aid-light_skin_tone:': '\U0001f9bb🏻',
#  ':ear_with_hearing_aid-medium-dark_skin_tone:': '\U0001f9bb🏾',
#  ':ear_with_hearing_aid-medium-light_skin_tone:': '\U0001f9bb🏼',
#  ':ear_with_hearing_aid-medium_skin_tone:': '\U0001f9bb🏽',
#  ':ear_with_hearing_aid:': '\U0001f9bb',
#  ':egg:': '🥚',
#  ':eggplant:': '🍆',
#  ':eight-pointed_star:': '✴',
#  ':eight-pointed_star_selector:': '✴️',
#  ':eight-spoked_asterisk:': '✳',
#  ':eight-spoked_asterisk_selector:': '✳️',
#  ':eight-thirty:': '🕣',
#  ':eight_o’clock:': '🕗',
#  ':eject_button:': '⏏',
#  ':eject_button_selector:': '⏏️',
#  ':electric_plug:': '🔌',
#  ':elephant:': '🐘',
#  ':eleven-thirty:': '🕦',
#  ':eleven_o’clock:': '🕚',
#  ':elf:': '🧝',
#  ':elf_dark_skin_tone:': '🧝🏿',
#  ':elf_light_skin_tone:': '🧝🏻',
#  ':elf_medium-dark_skin_tone:': '🧝🏾',
#  ':elf_medium-light_skin_tone:': '🧝🏼',
#  ':elf_medium_skin_tone:': '🧝🏽',
#  ':envelope:': '✉',
#  ':envelope_selector:': '✉️',
#  ':envelope_with_arrow:': '📩',
#  ':euro_banknote:': '💶',
#  ':evergreen_tree:': '🌲',
#  ':ewe:': '🐑',
#  ':exclamation_mark:': '❗',
#  ':exclamation_question_mark:': '⁉',
#  ':exclamation_question_mark_selector:': '⁉️',
#  ':exploding_head:': '🤯',
#  ':expressionless_face:': '😑',
#  ':eye:': '👁',
#  ':eye_in_speech_bubble:': '👁\u200d🗨',
#  ':eye_in_speech_bubble_2:': '👁\u200d🗨️',
#  ':eye_in_speech_bubble_3:': '👁️\u200d🗨️',
#  ':eye_in_speech_bubble_selector:': '👁️\u200d🗨',
#  ':eye_selector:': '👁️',
#  ':eyes:': '👀',
#  ':face_blowing_a_kiss:': '😘',
#  ':face_savoring_food:': '😋',
#  ':face_screaming_in_fear:': '😱',
#  ':face_vomiting:': '🤮',
#  ':face_with_hand_over_mouth:': '🤭',
#  ':face_with_head-bandage:': '🤕',
#  ':face_with_medical_mask:': '😷',
#  ':face_with_monocle:': '🧐',
#  ':face_with_open_mouth:': '😮',
#  ':face_with_raised_eyebrow:': '🤨',
#  ':face_with_rolling_eyes:': '🙄',
#  ':face_with_steam_from_nose:': '😤',
#  ':face_with_symbols_on_mouth:': '🤬',
#  ':face_with_tears_of_joy:': '😂',
#  ':face_with_thermometer:': '🤒',
#  ':face_with_tongue:': '😛',
#  ':face_without_mouth:': '😶',
#  ':factory:': '🏭',
#  ':fairy:': '🧚',
#  ':fairy_dark_skin_tone:': '🧚🏿',
#  ':fairy_light_skin_tone:': '🧚🏻',
#  ':fairy_medium-dark_skin_tone:': '🧚🏾',
#  ':fairy_medium-light_skin_tone:': '🧚🏼',
#  ':fairy_medium_skin_tone:': '🧚🏽',
#  ':falafel:': '\U0001f9c6',
#  ':fallen_leaf:': '🍂',
#  ':family:': '👪',
#  ':family_man_boy:': '👨\u200d👦',
#  ':family_man_boy_boy:': '👨\u200d👦\u200d👦',
#  ':family_man_girl:': '👨\u200d👧',
#  ':family_man_girl_boy:': '👨\u200d👧\u200d👦',
#  ':family_man_girl_girl:': '👨\u200d👧\u200d👧',
#  ':family_man_man_boy:': '👨\u200d👨\u200d👦',
#  ':family_man_man_boy_boy:': '👨\u200d👨\u200d👦\u200d👦',
#  ':family_man_man_girl:': '👨\u200d👨\u200d👧',
#  ':family_man_man_girl_boy:': '👨\u200d👨\u200d👧\u200d👦',
#  ':family_man_man_girl_girl:': '👨\u200d👨\u200d👧\u200d👧',
#  ':family_man_woman_boy:': '👨\u200d👩\u200d👦',
#  ':family_man_woman_boy_boy:': '👨\u200d👩\u200d👦\u200d👦',
#  ':family_man_woman_girl:': '👨\u200d👩\u200d👧',
#  ':family_man_woman_girl_boy:': '👨\u200d👩\u200d👧\u200d👦',
#  ':family_man_woman_girl_girl:': '👨\u200d👩\u200d👧\u200d👧',
#  ':family_woman_boy:': '👩\u200d👦',
#  ':family_woman_boy_boy:': '👩\u200d👦\u200d👦',
#  ':family_woman_girl:': '👩\u200d👧',
#  ':family_woman_girl_boy:': '👩\u200d👧\u200d👦',
#  ':family_woman_girl_girl:': '👩\u200d👧\u200d👧',
#  ':family_woman_woman_boy:': '👩\u200d👩\u200d👦',
#  ':family_woman_woman_boy_boy:': '👩\u200d👩\u200d👦\u200d👦',
#  ':family_woman_woman_girl:': '👩\u200d👩\u200d👧',
#  ':family_woman_woman_girl_boy:': '👩\u200d👩\u200d👧\u200d👦',
#  ':family_woman_woman_girl_girl:': '👩\u200d👩\u200d👧\u200d👧',
#  ':fast-forward_button:': '⏩',
#  ':fast_down_button:': '⏬',
#  ':fast_reverse_button:': '⏪',
#  ':fast_up_button:': '⏫',
#  ':fax_machine:': '📠',
#  ':fearful_face:': '😨',
#  ':female_sign:': '♀',
#  ':female_sign_selector:': '♀️',
#  ':ferris_wheel:': '🎡',
#  ':ferry:': '⛴',
#  ':ferry_selector:': '⛴️',
#  ':field_hockey:': '🏑',
#  ':file_cabinet:': '🗄',
#  ':file_cabinet_selector:': '🗄️',
#  ':file_folder:': '📁',
#  ':film_frames:': '🎞',
#  ':film_frames_selector:': '🎞️',
#  ':film_projector:': '📽',
#  ':film_projector_selector:': '📽️',
#  ':fire:': '🔥',
#  ':fire_engine:': '🚒',
#  ':fire_extinguisher:': '🧯',
#  ':firecracker:': '🧨',
#  ':fireworks:': '🎆',
#  ':first_quarter_moon:': '🌓',
#  ':first_quarter_moon_face:': '🌛',
#  ':fish:': '🐟',
#  ':fish_cake_with_swirl:': '🍥',
#  ':fishing_pole:': '🎣',
#  ':five-thirty:': '🕠',
#  ':five_o’clock:': '🕔',
#  ':flag_in_hole:': '⛳',
#  ':flamingo:': '\U0001f9a9',
#  ':flashlight:': '🔦',
#  ':flat_shoe:': '🥿',
#  ':fleur-de-lis:': '⚜',
#  ':fleur-de-lis_selector:': '⚜️',
#  ':flexed_biceps:': '💪',
#  ':flexed_biceps_dark_skin_tone:': '💪🏿',
#  ':flexed_biceps_light_skin_tone:': '💪🏻',
#  ':flexed_biceps_medium-dark_skin_tone:': '💪🏾',
#  ':flexed_biceps_medium-light_skin_tone:': '💪🏼',
#  ':flexed_biceps_medium_skin_tone:': '💪🏽',
#  ':floppy_disk:': '💾',
#  ':flower_playing_cards:': '🎴',
#  ':flushed_face:': '😳',
#  ...}

# %%
emoji_dict = {      "0": "\u2764\uFE0F",    
                    "1": ":baseball:",
                    "2": ":beaming_face_with_smiling_eyes:",
                    "3": ":downcast_face_with_sweat:",
                    "4": ":fork_and_knife:",
                   }

# %%
for e in emoji_dict.values():
    print(emoji.emojize(e))
# Out:
# ❤️
# ⚾
# 😁
# 😓
# 🍴

# %%
train_data = pd.read_csv("train_emoji.csv", header=None)
test_data =  pd.read_csv("test_emoji.csv", header=None)

# %%
train_data.head()
# Out:
#                                  0  1   2     3
# 0           never talk to me again  3 NaN   NaN
# 1  I am proud of your achievements  2 NaN   NaN
# 2   It is the worst day in my life  3 NaN   NaN
# 3                 Miss you so much  0 NaN   [0]
# 4                     food is life  4 NaN   NaN

# %%
train_data.drop(columns=[2, 3], inplace=True)

# %%
train_data.columns = ["Text", 'Label']

# %%
test_data.columns = ['Text', 'Label']

# %%
train_data.head()
# Out:
#                               Text  Label
# 0           never talk to me again      3
# 1  I am proud of your achievements      2
# 2   It is the worst day in my life      3
# 3                 Miss you so much      0
# 4                     food is life      4

# %%
x_train = train_data['Text'].values
y_train = train_data['Label'].values

x_test = test_data['Text'].values
y_test = test_data['Label'].values

# %%
y_train
# Out:
# array([3, 2, 3, 0, 4, 0, 3, 2, 3, 1, 3, 3, 1, 3, 2, 3, 2, 3, 1, 2, 3, 0,
#        2, 2, 2, 1, 4, 2, 2, 4, 0, 3, 4, 2, 0, 3, 2, 2, 3, 4, 2, 2, 0, 2,
#        3, 0, 3, 2, 4, 3, 0, 3, 3, 3, 4, 2, 1, 1, 1, 2, 3, 1, 0, 0, 0, 3,
#        4, 4, 2, 2, 1, 2, 0, 3, 2, 2, 0, 0, 3, 1, 2, 1, 2, 2, 4, 3, 3, 2,
#        4, 0, 0, 0, 3, 3, 3, 2, 0, 1, 2, 3, 0, 2, 2, 2, 3, 2, 2, 2, 4, 1,
#        1, 3, 3, 4, 1, 2, 1, 1, 3, 1, 0, 4, 0, 3, 3, 4, 4, 1, 4, 3, 0, 2],
#       dtype=int64)

# %%
x_train.shape
# Out:
# (132,)

# %%
x_test.shape
# Out:
# (56,)

# %%
for i in range(19, 29):
    print(x_train[i], emoji.emojize(emoji_dict[str(y_train[i])]))
# Out:
# I will celebrate soon 😁
# So sad you are not coming 😓
# She is my dearest love ❤️
# Good job 😁
# It was funny lol 😁
# candy is life  😁
# The chicago cubs won again ⚾
# I am hungry 🍴
# I am so excited to see you after so long 😁
# you did well on you exam 😁

# %%
f = open("glove.6B.50d.txt", encoding='utf8')

# %%
embedding_index = {}

for line in f:
    values = line.split()
    word = values[0]
    emb = np.array(values[1:], dtype ='float')
    
    embedding_index[word] = emb

# %%
embedding_index['america']
embedding_index['apple'].shape
# Out:
# (50,)

# %%
def get_embedding_output(X):
    maxLen = 10
    embedding_output = np.zeros((len(X), maxLen, 50))
    
    for ix in range(X.shape[0]):
        X[ix] = X[ix].split()
        
        for ij in range(len(X[ix])):
            embedding_output[ix][ij] = embedding_index[X[ix][ij].lower()]
            
    return embedding_output

# %%
train_embeddings = get_embedding_output(x_train)

# %%
test_embeddings = get_embedding_output(x_test)

# %%
train_embeddings.shape
# Out:
# (132, 10, 50)

# %%
test_embeddings.shape
# Out:
# (56, 10, 50)

# %%
from keras.utils import to_categorical

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
y_train.shape
# Out:
# (132, 5)

# %%
y_test.shape
# Out:
# (56, 5)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, SimpleRNN

# %%
model = Sequential()
model.add(LSTM(units=64, input_shape =(10, 50), return_sequences= True ))
model.add(Dropout(0.3))
model.add(LSTM(units = 32))
model.add(Dropout(0.3))
model.add(Dense(units= 10, activation= 'tanh'))
model.add(Dense(units= 5, activation= 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 64)            29440
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 64)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                330
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 55
# =================================================================
# Total params: 42,241
# Trainable params: 42,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

# %%
# Callbacks

hist = model.fit(train_embeddings, y_train, validation_split=0.1 , shuffle=True, batch_size=64, epochs=50 )
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 380ms/step - loss: 1.5896 - accuracy: 0.1780 - val_loss: 1.6112 - val_accuracy: 0.2857
# Epoch 2/50
# 2/2 [==============================] - 0s 27ms/step - loss: 1.5310 - accuracy: 0.3220 - val_loss: 1.5967 - val_accuracy: 0.2857
# Epoch 3/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.5217 - accuracy: 0.2542 - val_loss: 1.5965 - val_accuracy: 0.2857
# Epoch 4/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.5213 - accuracy: 0.2458 - val_loss: 1.5983 - val_accuracy: 0.2857
# Epoch 5/50
# 2/2 [==============================] - 0s 30ms/step - loss: 1.4980 - accuracy: 0.2966 - val_loss: 1.5909 - val_accuracy: 0.3571
# Epoch 6/50
# 2/2 [==============================] - 0s 24ms/step - loss: 1.4704 - accuracy: 0.2966 - val_loss: 1.5813 - val_accuracy: 0.2857
# Epoch 7/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4718 - accuracy: 0.3729 - val_loss: 1.5617 - val_accuracy: 0.2143
# Epoch 8/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4395 - accuracy: 0.3729 - val_loss: 1.5346 - val_accuracy: 0.1429
# Epoch 9/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4041 - accuracy: 0.3983 - val_loss: 1.5014 - val_accuracy: 0.2143
# Epoch 10/50
# 2/2 [==============================] - 0s 26ms/step - loss: 1.3750 - accuracy: 0.4831 - val_loss: 1.4602 - val_accuracy: 0.2143
# Epoch 11/50
# 2/2 [==============================] - 0s 26ms/step - loss: 1.3486 - accuracy: 0.5254 - val_loss: 1.4092 - val_accuracy: 0.3571
# Epoch 12/50
# 2/2 [==============================] - 0s 27ms/step - loss: 1.3164 - accuracy: 0.5339 - val_loss: 1.3539 - val_accuracy: 0.4286
# Epoch 13/50
# 2/2 [==============================] - 0s 26ms/step - loss: 1.2932 - accuracy: 0.5424 - val_loss: 1.2994 - val_accuracy: 0.5000
# Epoch 14/50
# 2/2 [==============================] - 0s 26ms/step - loss: 1.2391 - accuracy: 0.6186 - val_loss: 1.2567 - val_accuracy: 0.6429
# Epoch 15/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1735 - accuracy: 0.6102 - val_loss: 1.2204 - val_accuracy: 0.6429
# Epoch 16/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1591 - accuracy: 0.6271 - val_loss: 1.1901 - val_accuracy: 0.5714
# Epoch 17/50
# 2/2 [==============================] - 0s 28ms/step - loss: 1.1243 - accuracy: 0.6356 - val_loss: 1.1532 - val_accuracy: 0.5000
# Epoch 18/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.0510 - accuracy: 0.6695 - val_loss: 1.1155 - val_accuracy: 0.5000
# Epoch 19/50
# 2/2 [==============================] - 0s 26ms/step - loss: 1.0256 - accuracy: 0.6695 - val_loss: 1.0600 - val_accuracy: 0.5000
# Epoch 20/50
# 2/2 [==============================] - 0s 26ms/step - loss: 1.0065 - accuracy: 0.6780 - val_loss: 1.0290 - val_accuracy: 0.6429
# Epoch 21/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.9333 - accuracy: 0.7458 - val_loss: 0.9981 - val_accuracy: 0.6429
# Epoch 22/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.9185 - accuracy: 0.7119 - val_loss: 0.9810 - val_accuracy: 0.6429
# Epoch 23/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.8152 - accuracy: 0.7966 - val_loss: 0.9960 - val_accuracy: 0.6429
# Epoch 24/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.7928 - accuracy: 0.7712 - val_loss: 1.0779 - val_accuracy: 0.5000
# Epoch 25/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.7655 - accuracy: 0.8051 - val_loss: 1.1022 - val_accuracy: 0.5714
# Epoch 26/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.7146 - accuracy: 0.8051 - val_loss: 1.0771 - val_accuracy: 0.5714
# Epoch 27/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6976 - accuracy: 0.8051 - val_loss: 1.0117 - val_accuracy: 0.7143
# Epoch 28/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6918 - accuracy: 0.7881 - val_loss: 1.0206 - val_accuracy: 0.6429
# Epoch 29/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5981 - accuracy: 0.8559 - val_loss: 1.1102 - val_accuracy: 0.5714
# Epoch 30/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6317 - accuracy: 0.8644 - val_loss: 1.0984 - val_accuracy: 0.6429
# Epoch 31/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5642 - accuracy: 0.8644 - val_loss: 1.0926 - val_accuracy: 0.5714
# Epoch 32/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5371 - accuracy: 0.8898 - val_loss: 1.0920 - val_accuracy: 0.5714
# Epoch 33/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5166 - accuracy: 0.8644 - val_loss: 1.0830 - val_accuracy: 0.6429
# Epoch 34/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4860 - accuracy: 0.8898 - val_loss: 0.9974 - val_accuracy: 0.6429
# Epoch 35/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4987 - accuracy: 0.8729 - val_loss: 1.1191 - val_accuracy: 0.5714
# Epoch 36/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4468 - accuracy: 0.9068 - val_loss: 1.1366 - val_accuracy: 0.5714
# Epoch 37/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4861 - accuracy: 0.8644 - val_loss: 1.1246 - val_accuracy: 0.5714
# Epoch 38/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4344 - accuracy: 0.8898 - val_loss: 1.1715 - val_accuracy: 0.5714
# Epoch 39/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4412 - accuracy: 0.8644 - val_loss: 1.0743 - val_accuracy: 0.6429
# Epoch 40/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4210 - accuracy: 0.8983 - val_loss: 0.8519 - val_accuracy: 0.7143
# Epoch 41/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3989 - accuracy: 0.8983 - val_loss: 0.8892 - val_accuracy: 0.6429
# Epoch 42/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3924 - accuracy: 0.9068 - val_loss: 1.0389 - val_accuracy: 0.6429
# Epoch 43/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3703 - accuracy: 0.9322 - val_loss: 1.1119 - val_accuracy: 0.5714
# Epoch 44/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3797 - accuracy: 0.9322 - val_loss: 1.0953 - val_accuracy: 0.6429
# Epoch 45/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3477 - accuracy: 0.9407 - val_loss: 1.0632 - val_accuracy: 0.6429
# Epoch 46/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3386 - accuracy: 0.9322 - val_loss: 0.9264 - val_accuracy: 0.6429
# Epoch 47/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3115 - accuracy: 0.9407 - val_loss: 0.9411 - val_accuracy: 0.5714
# Epoch 48/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3243 - accuracy: 0.9237 - val_loss: 1.0078 - val_accuracy: 0.5714
# Epoch 49/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3064 - accuracy: 0.9407 - val_loss: 1.0735 - val_accuracy: 0.5714
# Epoch 50/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2790 - accuracy: 0.9492 - val_loss: 1.0661 - val_accuracy: 0.5714

# %%
model.evaluate(test_embeddings, y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0593 - accuracy: 0.6429
# [1.0593081712722778, 0.6428571343421936]

# %%
pred = model.predict_classes(test_embeddings)
# Out:
# WARNING:tensorflow:From <ipython-input-33-194ed36a1319>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
pred
# Out:
# array([4, 3, 2, 2, 2, 2, 3, 2, 4, 2, 1, 2, 0, 3, 1, 3, 3, 2, 3, 2, 0, 3,
#        4, 2, 3, 3, 2, 0, 1, 2, 0, 1, 3, 2, 0, 1, 2, 4, 1, 2, 1, 0, 0, 1,
#        2, 1, 3, 2, 3, 1, 3, 0, 3, 2, 2, 3], dtype=int64)

# %%
x_test
# Out:
# array([list(['I', 'want', 'to', 'eat']),
#        list(['he', 'did', 'not', 'answer']),
#        list(['he', 'got', 'a', 'raise']),
#        list(['she', 'got', 'me', 'a', 'present']),
#        list(['ha', 'ha', 'ha', 'it', 'was', 'so', 'funny']),
#        list(['he', 'is', 'a', 'good', 'friend']),
#        list(['I', 'am', 'upset']),
#        list(['We', 'had', 'such', 'a', 'lovely', 'dinner', 'tonight']),
#        list(['where', 'is', 'the', 'food']),
#        list(['Stop', 'making', 'this', 'joke', 'ha', 'ha', 'ha']),
#        list(['where', 'is', 'the', 'ball']), list(['work', 'is', 'hard']),
#        list(['This', 'girl', 'is', 'messing', 'with', 'me']),
#        list(['are', 'you', 'serious', 'ha', 'ha']),
#        list(['Let', 'us', 'go', 'play', 'baseball']),
#        list(['This', 'stupid', 'grader', 'is', 'not', 'working']),
#        list(['work', 'is', 'horrible']),
#        list(['Congratulation', 'for', 'having', 'a', 'baby']),
#        list(['stop', 'messing', 'around']),
#        list(['any', 'suggestions', 'for', 'dinner']),
#        list(['I', 'love', 'taking', 'breaks']),
#        list(['you', 'brighten', 'my', 'day']),
#        list(['I', 'boiled', 'rice']), list(['she', 'is', 'a', 'bully']),
#        list(['Why', 'are', 'you', 'feeling', 'bad']),
#        list(['I', 'am', 'upset']),
#        list(['I', 'worked', 'during', 'my', 'birthday']),
#        list(['My', 'grandmother', 'is', 'the', 'love', 'of', 'my', 'life']),
#        list(['enjoy', 'your', 'break']),
#        list(['valentine', 'day', 'is', 'near']),
#        list(['I', 'miss', 'you', 'so', 'much']),
#        list(['throw', 'the', 'ball']),
#        list(['My', 'life', 'is', 'so', 'boring']),
#        list(['she', 'said', 'yes']),
#        list(['will', 'you', 'be', 'my', 'valentine']),
#        list(['he', 'can', 'pitch', 'really', 'well']),
#        list(['dance', 'with', 'me']), list(['I', 'am', 'starving']),
#        list(['See', 'you', 'at', 'the', 'restaurant']),
#        list(['I', 'like', 'to', 'laugh']),
#        list(['I', 'will', 'go', 'dance']),
#        list(['I', 'like', 'your', 'jacket']), list(['i', 'miss', 'her']),
#        list(['what', 'is', 'your', 'favorite', 'baseball', 'game']),
#        list(['Good', 'job']),
#        list(['I', 'love', 'to', 'the', 'stars', 'and', 'back']),
#        list(['What', 'you', 'did', 'was', 'awesome']),
#        list(['ha', 'ha', 'ha', 'lol']), list(['I', 'want', 'to', 'joke']),
#        list(['go', 'away']), list(['yesterday', 'we', 'lost', 'again']),
#        list(['family', 'is', 'all', 'I', 'have']),
#        list(['you', 'are', 'failing', 'this', 'exercise']),
#        list(['Good', 'joke']),
#        list(['You', 'totally', 'deserve', 'this', 'prize']),
#        list(['I', 'did', 'not', 'have', 'breakfast'])], dtype=object)

# %%
for i in range(len(pred)):
    
    print(" ".join(x_test[i]))
    
    emote = emoji_dict[str(pred[i])]
    print(emoji.emojize(emote))
# Out:
# I want to eat
# 🍴
# he did not answer
# 😓
# he got a raise
# 😁
# she got me a present
# 😁
# ha ha ha it was so funny
# 😁
# he is a good friend
# 😁
# I am upset
# 😓
# We had such a lovely dinner tonight
# 😁
# where is the food
# 🍴
# Stop making this joke ha ha ha
# 😁
# where is the ball
# ⚾
# work is hard
# 😁
# This girl is messing with me
# ❤️
# are you serious ha ha
# 😓
# Let us go play baseball
# ⚾
# This stupid grader is not working
# 😓
# work is horrible
# 😓
# Congratulation for having a baby
# 😁
# stop messing around
# 😓
# any suggestions for dinner
# 😁
# I love taking breaks
# ❤️
# you brighten my day
# 😓
# I boiled rice
# 🍴
# she is a bully
# 😁
# Why are you feeling bad
# 😓
# I am upset
# 😓
# I worked during my birthday
# 😁
# My grandmother is the love of my life
# ❤️
# enjoy your break
# ⚾
# valentine day is near
# 😁
# I miss you so much
# ❤️
# throw the ball
# ⚾
# My life is so boring
# 😓
# she said yes
# 😁
# will you be my valentine
# ❤️
# he can pitch really well
# ⚾
# dance with me
# 😁
# I am starving
# 🍴
# See you at the restaurant
# ⚾
# I like to laugh
# 😁
# I will go dance
# ⚾
# I like your jacket
# ❤️
# i miss her
# ❤️
# what is your favorite baseball game
# ⚾
# Good job
# 😁
# I love to the stars and back
# ⚾
# What you did was awesome
# 😓
# ha ha ha lol
# 😁
# I want to joke
# 😓
# go away
# ⚾
# yesterday we lost again
# 😓
# family is all I have
# ❤️
# you are failing this exercise
# 😓
# Good joke
# 😁
# You totally deserve this prize
# 😁
# I did not have breakfast
# 😓

# %%
x_query = "i love to sleep".lower()

# %%
embedding_x_query = []

# %%
for w in x_query.split():
    print(w)
    emb = embedding_index[w]
    embedding_x_query.append(emb)
# Out:
# i
# love
# to
# sleep

# %%
embedding_x_query = np.array(embedding_x_query)

# %%
embedding_x_query.shape
# Out:
# (4, 50)

# %%
if embedding_x_query.shape[0] <10:
    embedding_x_query = np.vstack((embedding_x_query , np.zeros((10 - len(x_query.split()), 50))))

# %%
embedding_x_query = embedding_x_query.reshape(1, 10, 50)

# %%
embedding_x_query.shape
# Out:
# (1, 10, 50)

# %%
p = model.predict_classes(embedding_x_query)

# %%
print(emoji.emojize(emoji_dict[str(p[0])]))
# Out:
# 😓
